# %% [markdown]
# # Pooling before/after batch normalization

# %% [markdown]
# In this example, I would like to explore the possible effects of the order in which a pooling layer and a normalization layer are applied in convolutional neural networks.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd drive/MyDrive/Clase_3/Tarea_1
# Out:
# /content/drive/MyDrive/Clase_3/Tarea_1

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.datasets import fashion_mnist
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D, Input
from tensorflow.keras.layers import BatchNormalization, Dropout
from tensorflow.keras.optimizers import Adam, SGD, RMSprop, Adagrad
from tensorflow.keras.utils import plot_model, to_categorical

from keras.callbacks import ModelCheckpoint, EarlyStopping

import matplotlib.pyplot as plt
import numpy as np

from sklearn.utils import shuffle

# %% [markdown]
# ## Building the data sets

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# take 10% as validation set
n_val = int(0.1*len(x_train))

x_val = x_train[:n_val]
x_train = x_train[n_val:]

y_val = y_train[:n_val]
y_train = y_train[n_val:]

print("Training: Data ({}), Labels ({})".format(x_train.shape, y_train.shape))
print("Validation: Data ({}), Labels ({})".format(x_val.shape, y_val.shape))
print("Testing: Data ({}), Labels ({})".format(x_test.shape, y_test.shape))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 32768/29515 [=================================] - 0s 0us/step
# 40960/29515 [=========================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26427392/26421880 [==============================] - 0s 0us/step
# 26435584/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 16384/5148 [===============================================================================================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4423680/4422102 [==============================] - 0s 0us/step
# 4431872/4422102 [==============================] - 0s 0us/step
# Training: Data ((54000, 28, 28)), Labels ((54000, 10))
# Validation: Data ((6000, 28, 28)), Labels ((6000, 10))
# Testing: Data ((10000, 28, 28)), Labels ((10000, 10))

# %%
# (#,28,28) => (#,28,28,1)
# uint8 => float
# [0,255] => [0,1]
x_train = np.expand_dims(x_train, axis=-1).astype("float32")/255.0
x_val = np.expand_dims(x_val, axis=-1).astype("float32")/255.0
x_test = np.expand_dims(x_test, axis=-1).astype("float32")/255.0

# %%
name_labels = ['T-shirt/top', 
               'Trouser', 
               'Pullover', 
               'Dress', 
               'Coat', 
               'Sandal', 
               'Shirt', 
               'Sneaker', 
               'Bag', 
               'Ankle boot']

n_classes = len(name_labels)

# %%
batch_size = 64
# Generador para Entrenamiento, con flips horizontal y vertical
gen_train = ImageDataGenerator(horizontal_flip=True,
                               vertical_flip=True)
# Generador para Validación
gen_val = ImageDataGenerator()

data_gen_train = gen_train.flow(x_train, y_train, batch_size=batch_size)
data_gen_val = gen_val.flow(x_val, y_val, batch_size=batch_size)

# %%
x_temp, y_tem = data_gen_train.next()
print(x_temp.shape, y_tem.shape)
# Out:
# (64, 28, 28, 1) (64, 10)

# %% [markdown]
# ## Model APIs for both approaches

# %%
# Normalization before pooling
def get_model_norm_pool(filters, 
                        n_classes, 
                        k=3, 
                        name="my_model", 
                        padding="same", 
                        batch_norm=False, 
                        dropout=None):
    input_layer = Input(shape=(28,28,1))
    x = Conv2D(filters[0], (k,k), activation="relu", padding=padding)(input_layer)
    if batch_norm: x = BatchNormalization()(x)
    x = MaxPooling2D(2,2)(x)
    if dropout is not None: x = Dropout(dropout)(x)
    
    for n in filters[1:]:
        x = Conv2D(n, (k,k), activation="relu", padding=padding)(x)
        if batch_norm: x = BatchNormalization()(x)
        x = MaxPooling2D(2,2)(x)
        if dropout is not None: x = Dropout(dropout)(x)

    x = Flatten()(x)
    x = Dense(100, activation="relu")(x)
    output_layer = Dense(n_classes, activation="softmax")(x)
    
    model = Model(inputs=input_layer, outputs=output_layer, name=name)

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss="categorical_crossentropy",
                  metrics=['accuracy']
                  )
    return model

# %%
# Pooling before normalization
def get_model_pool_norm(filters, 
                        n_classes, 
                        k=3, 
                        name="my_model", 
                        padding="same", 
                        batch_norm=False, 
                        dropout=None):
    input_layer = Input(shape=(28,28,1))
    x = Conv2D(filters[0], (k,k), activation="relu", padding=padding)(input_layer)
    x = MaxPooling2D(2,2)(x)
    if batch_norm: x = BatchNormalization()(x)
    if dropout is not None: x = Dropout(dropout)(x)
    
    for n in filters[1:]:
        x = Conv2D(n, (k,k), activation="relu", padding=padding)(x)
        x = MaxPooling2D(2,2)(x)
        if batch_norm: x = BatchNormalization()(x)
        if dropout is not None: x = Dropout(dropout)(x)

    x = Flatten()(x)
    x = Dense(100, activation="relu")(x)
    output_layer = Dense(n_classes, activation="softmax")(x)
    
    model = Model(inputs=input_layer, outputs=output_layer, name=name)

    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss="categorical_crossentropy",
                  metrics=['accuracy']
                  )
    return model

# %% [markdown]
# ## Test 1: kernel = 3x3, pooling = 2x2, depths = [16, 32]

# %%
norm_bf_pool = get_model_norm_pool([16, 32], 
                                   n_classes, 
                                   name = "Norm_before_pooling", 
                                   batch_norm = True)

pool_bf_norm = get_model_pool_norm([16, 32], 
                                   n_classes, 
                                   name = "Pooling_before_norm", 
                                   batch_norm = True)

# %%
print("Model: {}, Parameters: {}".format(norm_bf_pool.name,
                                       norm_bf_pool.count_params()))

print("Model: {}, Parameters: {}".format(pool_bf_norm.name,
                                       pool_bf_norm.count_params()))
# Out:
# Model: Norm_before_pooling, Parameters: 162902
# Model: Pooling_before_norm, Parameters: 162902

# %%
plot_model(norm_bf_pool, to_file="norm_bf_pool.png", show_shapes=True)

# %%
plot_model(pool_bf_norm, to_file="pool_bf_norm.png", show_shapes=True)

# %%
def get_ckpt(ckpt_name):
  return ModelCheckpoint(ckpt_name,
                         mode="max", 
                         save_best_only=True, 
                         monitor="val_accuracy", 
                         verbose=1)

# %%
# Callbacks
# ModelCheckpoint guardara el modelo cada vez que exista una mejora
# en el accuracy del conjunto de validación
mode_as_pool_bf_norm = get_ckpt("class_model_pool_bf_norm.h5")
mode_as_norm_bf_pool = get_ckpt("class_model_norm_bf_pool.h5")

# EarlyStopping terminara el entrenamiento si no existe una mejora
# en el accuracy en 40 epocas
early_stopping = EarlyStopping(patience=40, 
                               verbose=1, 
                               mode="auto")

callbacks_pool_bf_norm = [mode_as_pool_bf_norm, early_stopping]
callbacks_norm_bf_pool = [mode_as_norm_bf_pool, early_stopping]

# %%
history_norm_bf_pool = norm_bf_pool.fit(data_gen_train,epochs=200,validation_data=data_gen_val,callbacks=callbacks_norm_bf_pool)
# Out:
# Epoch 1/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.4699 - accuracy: 0.8305
# Epoch 1: val_accuracy improved from -inf to 0.86600, saving model to class_model_norm_bf_pool.h5
# 844/844 [==============================] - 16s 5ms/step - loss: 0.4699 - accuracy: 0.8305 - val_loss: 0.3584 - val_accuracy: 0.8660
# Epoch 2/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.3297 - accuracy: 0.8803
# Epoch 2: val_accuracy improved from 0.86600 to 0.88800, saving model to class_model_norm_bf_pool.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.3292 - accuracy: 0.8805 - val_loss: 0.3018 - val_accuracy: 0.8880
# Epoch 3/200
# 841/844 [============================>.] - ETA: 0s - loss: 0
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1734 - accuracy: 0.9366 - val_loss: 0.3525 - val_accuracy: 0.8750
# Epoch 14/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1681 - accuracy: 0.9378
# Epoch 14: val_accuracy improved from 0.90933 to 0.91283, saving model to class_model_norm_bf_pool.h5
# 844/844 [==============================] - 5s 6ms/step - loss: 0.1683 - accuracy: 0.9377 - val_loss: 0.2543 - val_accuracy: 0.9128
# Epoch 15/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.1631 - accuracy: 0.9404
# Epoch 15: val_accuracy did not improve from 0.91283
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1631 - accuracy: 0.9404 - val_loss: 0.3700 - val_accuracy: 0.8772
# Epoch 16/200
# 835/844 [============================>.] - ETA: 0s - loss: 0.1595 - accuracy: 0.9420
# Epoch 16: val_accuracy improved from 0.91283 to 0.91450, saving model to class_model_norm_bf_pool.h5
# 844/844 [==============================] - 5s 6ms/step - loss: 0.1593 - accuracy: 0.9421 - val_loss: 0.2474 - val_accuracy: 0.9145
# Epoch 17/200
# 835/844 [============================>.] - ETA: 0s - loss: 0.1534 - accuracy: 0.9429
# Epoch 17: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1532 - accuracy: 0.9430 - val_loss: 0.3182 - val_accuracy: 0.8942
# Epoch 18/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1476 - accuracy: 0.9464
# Epoch 18: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1476 - accuracy: 0.9464 - val_loss: 0.2653 - val_accuracy: 0.9123
# Epoch 19/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.1453 - accuracy: 0.9470
# Epoch 19: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1454 - accuracy: 0.9470 - val_loss: 0.2508 - val_accuracy: 0.9127
# Epoch 20/200
# 844/844 [==============================] - ETA: 0s - loss: 0.1383 - accuracy: 0.9485
# Epoch 20: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1383 - accuracy: 0.9485 - val_loss: 0.2795 - val_accuracy: 0.9070
# Epoch 21/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1350 - accuracy: 0.9507
# Epoch 21: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1351 - accuracy: 0.9506 - val_loss: 0.2779 - val_accuracy: 0.9100
# Epoch 22/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.1329 - accuracy: 0.9505
# Epoch 22: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1329 - accuracy: 0.9504 - val_loss: 0.2934 - val_accuracy: 0.9095
# Epoch 23/200
# 835/844 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9540
# Epoch 23: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1272 - accuracy: 0.9541 - val_loss: 0.3014 - val_accuracy: 0.9047
# Epoch 24/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.1235 - accuracy: 0.9544
# Epoch 24: val_accuracy did not improve from 0.91450
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1235 - accuracy: 0.9543 - val_loss: 0.2783 - val_accuracy: 0.9108
# Epoch 25/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1231 - accuracy: 0.9545
# Epoch 25: val_accuracy improved from 0.91450 to 0.91650, saving model to class_model_norm_bf_pool.h5
# 844/844 [==============================] - 5s 6ms/step - loss: 0.1233 - accuracy: 0.9545 - val_loss: 0.2720 - val_accuracy: 0.9165
# Epoch 26/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1174 - accuracy: 0.9570
# Epoch 26: val_accuracy did not improve from 0.91650
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1176 - accuracy: 0.9570 - val_loss: 0.3526 - val_accuracy: 0.8927
# Epoch 27/200
# 841/844 [============================>.] - ETA: 0s - loss: 0
val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0779 - accuracy: 0.9707 - val_loss: 0.4127 - val_accuracy: 0.8998
# Epoch 44/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.0768 - accuracy: 0.9718
# Epoch 44: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0767 - accuracy: 0.9718 - val_loss: 0.3900 - val_accuracy: 0.9067
# Epoch 45/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.0741 - accuracy: 0.9737
# Epoch 45: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0742 - accuracy: 0.9737 - val_loss: 0.3473 - val_accuracy: 0.9182
# Epoch 46/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.0729 - accuracy: 0.9732
# Epoch 46: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0729 - accuracy: 0.9732 - val_loss: 0.3647 - val_accuracy: 0.9175
# Epoch 47/200
# 839/844 [============================>.] - ETA: 0s - loss: 0.0708 - accuracy: 0.9738
# Epoch 47: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0709 - accuracy: 0.9738 - val_loss: 0.3571 - val_accuracy: 0.9152
# Epoch 48/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.0698 - accuracy: 0.9740
# Epoch 48: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0699 - accuracy: 0.9739 - val_loss: 0.3742 - val_accuracy: 0.9195
# Epoch 49/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.0672 - accuracy: 0.9749
# Epoch 49: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0671 - accuracy: 0.9749 - val_loss: 0.3581 - val_accuracy: 0.9145
# Epoch 50/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.0681 - accuracy: 0.9747
# Epoch 50: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0682 - accuracy: 0.9746 - val_loss: 0.3854 - val_accuracy: 0.9107
# Epoch 51/200
# 834/844 [============================>.] - ETA: 0s - loss: 0.0671 - accuracy: 0.9753
# Epoch 51: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0675 - accuracy: 0.9752 - val_loss: 0.3641 - val_accuracy: 0.9142
# Epoch 52/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.0616 - accuracy: 0.9777
# Epoch 52: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0617 - accuracy: 0.9776 - val_loss: 0.3958 - val_accuracy: 0.9117
# Epoch 53/200
# 839/844 [============================>.] - ETA: 0s - loss: 0.0619 - accuracy: 0.9774
# Epoch 53: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0622 - accuracy: 0.9774 - val_loss: 0.4163 - val_accuracy: 0.9097
# Epoch 54/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.0628 - accuracy: 0.9769
# Epoch 54: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0627 - accuracy: 0.9770 - val_loss: 0.3965 - val_accuracy: 0.9173
# Epoch 55/200
# 839/844 [============================>.] - ETA: 0s - loss: 0.0625 - accuracy: 0.9773
# Epoch 55: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0624 - accuracy: 0.9774 - val_loss: 0.3600 - val_accuracy: 0.9150
# Epoch 56/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.0588 - accuracy: 0.9793
# Epoch 56: val_accuracy did not improve from 0.91950
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0588 - accuracy: 0.9793 - val_loss: 0.4351 - val_accuracy: 0.9052
# Epoch 56: early stopping

# %%
history_pool_bf_norm = pool_bf_norm.fit(data_gen_train,epochs=200,validation_data=data_gen_val,callbacks=callbacks_pool_bf_norm)
# Out:
# Epoch 1/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.4422 - accuracy: 0.8405
# Epoch 1: val_accuracy improved from -inf to 0.87333, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.4415 - accuracy: 0.8407 - val_loss: 0.3383 - val_accuracy: 0.8733
# Epoch 2/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.3065 - accuracy: 0.8873
# Epoch 2: val_accuracy improved from 0.87333 to 0.88567, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 4s 5ms/step - loss: 0.3066 - accuracy: 0.8873 - val_loss: 0.3160 - val_accuracy: 0.8857
# Epoch 3/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.2711 - accuracy: 0.9002
# Epoch 3: val_accuracy did not improve from 0.88567
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2712 - accuracy: 0.9003 - val_loss: 0.3206 - val_accuracy: 0.8813
# Epoch 4/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.2511 - accuracy: 0.9094
# Epoch 4: val_accuracy did not improve from 0.88567
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2511 - accuracy: 0.9093 - val_loss: 0.3135 - val_accuracy: 0.8838
# Epoch 5/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.2326 - accuracy: 0.9148
# Epoch 5: val_accuracy improved from 0.88567 to 0.89767, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.2327 - accuracy: 0.9149 - val_loss: 0.2741 - val_accuracy: 0.8977
# Epoch 6/200
# 836/844 [============================>.] - ETA: 0s - loss: 0.2226 - accuracy: 0.9179
# Epoch 6: val_accuracy improved from 0.89767 to 0.90467, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2224 - accuracy: 0.9179 - val_loss: 0.2538 - val_accuracy: 0.9047
# Epoch 7/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.2075 - accuracy: 0.9242
# Epoch 7: val_accuracy improved from 0.90467 to 0.91517, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2075 - accuracy: 0.9242 - val_loss: 0.2345 - val_accuracy: 0.9152
# Epoch 8/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.2007 - accuracy: 0.9265
# Epoch 8: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.2008 - accuracy: 0.9265 - val_loss: 0.2729 - val_accuracy: 0.9000
# Epoch 9/200
# 844/844 [==============================] - ETA: 0s - loss: 0.1935 - accuracy: 0.9287
# Epoch 9: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1935 - accuracy: 0.9287 - val_loss: 0.2974 - val_accuracy: 0.8920
# Epoch 10/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1826 - accuracy: 0.9319
# Epoch 10: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1824 - accuracy: 0.9320 - val_loss: 0.2738 - val_accuracy: 0.9027
# Epoch 11/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1738 - accuracy: 0.9365
# Epoch 11: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1737 - accuracy: 0.9365 - val_loss: 0.2883 - val_accuracy: 0.8952
# Epoch 12/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1669 - accuracy: 0.9377
# Epoch 12: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1670 - accuracy: 0.9377 - val_loss: 0.3924 - val_accuracy: 0.8672
# Epoch 13/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1583 - accuracy: 0.9410
# Epoch 13: val_accuracy did not improve from 0.91517
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1582 - accuracy: 0.9410 - val_loss: 0.2906 - val_accuracy: 0.9012
# Epoch 14/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.1536 - accuracy: 0.9430
# Epoch 14: val_accuracy improved from 0.91517 to 0.91667, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1536 - accuracy: 0.9430 - val_loss: 0.2376 - val_accuracy: 0.9167
# Epoch 15/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1514 - accuracy: 0.9433
# Epoch 15: val_accuracy did not improve from 0.91667
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1517 - accuracy: 0.9432 - val_loss: 0.2667 - val_accuracy: 0.9082
# Epoch 16/200
# 837/844 [============================>.] - ETA: 0s - loss: 0.1451 - accuracy: 0.9467
# Epoch 16: val_accuracy improved from 0.91667 to 0.91700, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1446 - accuracy: 0.9469 - val_loss: 0.2433 - val_accuracy: 0.9170
# Epoch 17/200
# 836/844 [============================>.] - ETA: 0s - loss: 0.1395 - accuracy: 0.9488
# Epoch 17: val_accuracy did not improve from 0.91700
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1395 - accuracy: 0.9488 - val_loss: 0.2447 - val_accuracy: 0.9153
# Epoch 18/200
# 836/844 [============================>.] - ETA: 0s - loss: 0.1370 - accuracy: 0.9498
# Epoch 18: val_accuracy did not improve from 0.91700
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1370 - accuracy: 0.9499 - val_loss: 0.2671 - val_accuracy: 0.9080
# Epoch 19/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.1296 - accuracy: 0.9521
# Epoch 19: val_accuracy improved from 0.91700 to 0.91900, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1295 - accuracy: 0.9521 - val_loss: 0.2493 - val_accuracy: 0.9190
# Epoch 20/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.1273 - accuracy: 0.9528
# Epoch 20: val_accuracy did not improve from 0.91900
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1274 - accuracy: 0.9528 - val_loss: 0.2493 - val_accuracy: 0.9132
# Epoch 21/200
# 843/844 [============================>.] - ETA: 0s - loss: 0.1224 - accuracy: 0.9550
# Epoch 21: val_accuracy did not improve from 0.91900
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1226 - accuracy: 0.9549 - val_loss: 0.2995 - val_accuracy: 0.9078
# Epoch 22/200
# 835/844 [============================>.] - ETA: 0s - loss: 0.1185 - accuracy: 0.9562
# Epoch 22: val_accuracy improved from 0.91900 to 0.92000, saving model to class_model_pool_bf_norm.h5
# 844/844 [==============================] - 5s 5ms/step - loss: 0.1185 - accuracy: 0.9562 - val_loss: 0.2443 - val_accuracy: 0.9200
# Epoch 23/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.1162 - accuracy: 0.9557
# Epoch 23: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1164 - accuracy: 0.9557 - val_loss: 0.2602 - val_accuracy: 0.9167
# Epoch 24/200
# 834/844 [============================>.] - ETA: 0s - loss: 0.1123 - accuracy: 0.9584
# Epoch 24: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1123 - accuracy: 0.9583 - val_loss: 0.2856 - val_accuracy: 0.9138
# Epoch 25/200
# 841/844 [============================>.] - ETA: 0s - loss: 0.1101 - accuracy: 0.9592
# Epoch 25: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.1100 - accuracy: 0.9592 - val_loss: 0.2685 - val_accuracy: 0.9150
# Epoch 26/200
# 840/844 [============================>.] - ETA: 0s - loss: 0.1037 - accuracy: 0.9624
# Epoch 26: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.
val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0633 - accuracy: 0.9768 - val_loss: 0.3587 - val_accuracy: 0.9158
# Epoch 45/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.0639 - accuracy: 0.9768
# Epoch 45: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0639 - accuracy: 0.9768 - val_loss: 0.3715 - val_accuracy: 0.9137
# Epoch 46/200
# 842/844 [============================>.] - ETA: 0s - loss: 0.0615 - accuracy: 0.9774
# Epoch 46: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0614 - accuracy: 0.9775 - val_loss: 0.3706 - val_accuracy: 0.9162
# Epoch 47/200
# 835/844 [============================>.] - ETA: 0s - loss: 0.0595 - accuracy: 0.9779
# Epoch 47: val_accuracy did not improve from 0.92000
# 844/844 [==============================] - 4s 5ms/step - loss: 0.0594 - accuracy: 0.9779 - val_loss: 0.3688 - val_accuracy: 0.9175
# Epoch 47: early stopping

# %%
fig_labels = ["Train CNN, Norm before Pool", 
              "Validation CNN, Norm before Pool",              
              "Train CNN, Pool before Norm",
              "Validation CNN, Pool before Norm"]

plt.figure(figsize=(15,10))

plt.subplot(2,1,1)
plt.plot(history_norm_bf_pool.history["loss"], "r-")
plt.plot(history_norm_bf_pool.history["val_loss"], "r--")
plt.plot(history_pool_bf_norm.history["loss"], "b-")
plt.plot(history_pool_bf_norm.history["val_loss"], "b--")
plt.xlabel("# Epoch")
plt.ylabel("Loss function")
plt.legend(fig_labels)
plt.title("Loss vs. Epoch")

plt.subplot(2,1,2)
plt.plot(history_norm_bf_pool.history["accuracy"], "r-")
plt.plot(history_norm_bf_pool.history["val_accuracy"], "r--")
plt.plot(history_pool_bf_norm.history["accuracy"], "b-")
plt.plot(history_pool_bf_norm.history["val_accuracy"], "b--")
plt.xlabel("# Epoch")
plt.ylabel("Accuracy")
plt.legend(fig_labels)
plt.title("Accuracy vs. Epoch")

plt.show()

# %%
gen_test = ImageDataGenerator()

data_gen_test = gen_train.flow(x_test, y_test, batch_size=batch_size)

# %%
print("Entrenamiento:")
scores_train_1 = norm_bf_pool.evaluate(data_gen_train)
scores_train_2 = pool_bf_norm.evaluate(data_gen_train)

print("Validación:")
scores_val_1 = norm_bf_pool.evaluate(data_gen_val)
scores_val_2 = pool_bf_norm.evaluate(data_gen_val)

print("Pruebas:")
scores_test_1 = norm_bf_pool.evaluate(data_gen_test)
scores_test_2 = pool_bf_norm.evaluate(data_gen_test)
# Out:
# Entrenamiento:
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0775 - accuracy: 0.9710
# 844/844 [==============================] - 3s 4ms/step - loss: 0.0663 - accuracy: 0.9744
# Validación:
# 94/94 [==============================] - 0s 4ms/step - loss: 0.4351 - accuracy: 0.9052
# 94/94 [==============================] - 0s 3ms/step - loss: 0.3688 - accuracy: 0.9175
# Pruebas:
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4705 - accuracy: 0.9057
# 157/157 [==============================] - 1s 4ms/step - loss: 0.4485 - accuracy: 0.9025

# %% [markdown]
# |Loss |Entrenamiento |Validación | -  |Accuracy |Entrenamiento |Validación|
# |-----|------|----------|------|----|---------|------|
# |NBP|0.0775|0.4351|- |             |0.9710| 0.9052 |
# |PBN|0.0663|0.3688|- |             |0.9744| 0.9175 |
#
# |Loss |Pruebas| -|Accuracy |Pruebas|
# |-----|-------|--|---------|------|
# |NBP|0.4705 |- | |0.9057|
# |PBN|0.4485|- | |0.9025|
